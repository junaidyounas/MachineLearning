# %%
# Filter in python
a = [1, 2, 3, 4, 5, 6, 7, 8]
new = list(filter(lambda x: x% 2== 0, a))
print(new)
# Out:
# [2, 4, 6, 8]

# %%
# Nested functions
def outer():
    def inner():
        return 'Hello'
    return inner()

print(outer())
# Out:
# Hello

# %%
# map with outer function
a = [1, 2, 3, 4, 5, 6, 7, 8]
def add(x):
    return x+1

new = list(map(add, a))
print(new)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Return the inner function
def multiplier(factor):
    def multiply(x):
        return x*factor
    return multiply

times3 = multiplier(3)
print(times3(4))
# Out:
# 12

# %%
# Filehandling
# !touch file.txt

# %%
# !echo 'Hello World!' > file.txt

# %%
with open("file.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Hello World!
#
# Hello World Again

# %%
with open("file.txt", 'a') as f:
    f.write('\nHello World Again')
    print(f)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='a' encoding='UTF-8'>

# %%
with open("file.txt", "r") as f:
    data = f.readlines()
    print(data)
# Out:
# ['Hello World!\n', '\n', 'Hello World Again']

# %%
with open('file.txt', 'w+') as f:
    f.write('NewLine')
    f.seek(1)
    data = f.read()
    
    print(data)
# Out:
# ewLine

# %%
with open("file.txt", "w+") as f:
    f.write("Python")
    f.seek(0)
    print(f.read())

print('hello')
# Out:
# Python
# hello

# %%
# Append and Read
with open("file.txt", "w+") as f:
    f.write("------1-------")
    f.seek(5)
    f.write("------2-------")
    f.seek(0)
    print(f.read())
# Out:
# -----------2-------

# %%
with open("file.txt", "w+") as f:
    f.write("Hello World")

    f.seek(6)          # Cursor 'W' par
    f.write("Python")

    f.seek(0)
    print(f.read())
# Out:
# Hello Python
